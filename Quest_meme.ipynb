# %% [markdown]
# <a href="https://colab.research.google.com/github/Dannatinjaca/PROGCOM-A/blob/main/Quest_meme.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![meme programacion.mp4](data:video/mp4;base64,...)
