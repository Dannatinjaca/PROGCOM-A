# %% [markdown]
# <a href="https://colab.research.google.com/github/Dannatinjaca/PROGCOM-A/blob/main/quest_codecombat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![codecombat .jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![codecombat calabozo.jpg](data:image/jpeg;base64,...)
