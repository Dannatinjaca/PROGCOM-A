# %% [markdown]
# <a href="https://colab.research.google.com/github/Dannatinjaca/PROGCOM-A/blob/main/EVIDENCIAS_CLASE_MICROBITS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# GRUPO:DANNA TINJACÁ-HEIDY HERNANDEZ

# %% [markdown]
# ![Imagen de WhatsApp 2025-04-25 a las 15.35.37_e4ad0d1e.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Imagen de WhatsApp 2025-04-25 a las 15.35.37_e4ad0d1e.jpg](data:image/jpeg;base64,...)
