# %% [markdown]
# <a href="https://colab.research.google.com/github/Dannatinjaca/PROGCOM-A/blob/main/Quest_piedra%2Cpapel%2Ctijeras%2Cspook_y_largartija.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Referencias utilizadas:
# Documentación de Python: Para entender mejor la estructura de diccionarios y funciones.
#
# https://docs.python.org/3/tutorial/datastructures.html
#
# ipywidgets: Para crear una interfaz interactiva en Google Colab.
#
# https://ipywidgets.readthedocs.io/en/stable/examples/Widget%20Basics.html
#
# Uso de random.choice en Python: Para generar elecciones aleatorias en el juego.
#
# https://docs.python.org/3/library/random.html
#
# Uso de IPython.display.HTML: Para mostrar resultados con estilo en Google Colab.
#
# https://ipython.readthedocs.io/en/stable/api/generated/IPython.display.html
#
# Reglas de Piedra, Papel, Tijera, Spock, Lagartija: Para entender cómo funciona el juego.
#
# https://es.wikipedia.org/wiki/Piedra,_papel,_tijera,_lagarto,_Spock
#
# VIDEO DE REFERENCIA:
# https://youtu.be/ocO24OFpxOM

# %%
import random
import ipywidgets as widgets
from IPython.display import display, HTML

# Opciones del juego con emojis
opciones = {
    "Piedra": "\U0000270A",
    "Papel": "\U0001F44F",
    "Tijera": "\U0000270C",
    "Spock": "\U0001F995",
    "Lagartija": "\U0001F98E"
}

# Reglas del juego
reglas = {
    "Piedra": ["Tijera", "Lagartija"],
    "Papel": ["Piedra", "Spock"],
    "Tijera": ["Papel", "Lagartija"],
    "Spock": ["Tijera", "Piedra"],
    "Lagartija": ["Papel", "Spock"]
}

def jugar(eleccion_usuario):
    eleccion_maquina = random.choice(list(opciones.keys()))

    resultado = ""
    if eleccion_usuario == eleccion_maquina:
        resultado = "\U0001F914 ¡Empate!"
    elif eleccion_maquina in reglas[eleccion_usuario]:
        resultado = "\U0001F389 ¡Ganaste!"
    else:
        resultado = "\U0001F62D ¡Perdiste!"

    mensaje = f"""
    <h2 style='text-align: center;'>
    Tú elegiste: {opciones[eleccion_usuario]} ({eleccion_usuario})<br>
    La máquina eligió: {opciones[eleccion_maquina]} ({eleccion_maquina})<br>
    <strong>{resultado}</strong>
    </h2>
    """
    display(HTML(mensaje))

# Botones de elección
botones = []
for opcion in opciones:
    boton = widgets.Button(description=f"{opciones[opcion]} {opcion}", layout=widgets.Layout(width='150px'))
    boton.style.button_color = "lightblue"
    boton.on_click(lambda b, op=opcion: jugar(op))
    botones.append(boton)

display(widgets.HBox(botones))
# Out:
# ...
#     <h2 style='text-align: center;'>
#     Tú elegiste: ✌ (Tijera)<br>
#     La máquina eligió: ✌ (Tijera)<br>
#     <strong>🤔 ¡Empate!</strong>
#     </h2>
#     <h2 style='text-align: center;'>
#     Tú elegiste: 🦎 (Lagartija)<br>
#     La máquina eligió: 🦕 (Spock)<br>
#     <strong>🎉 ¡Ganaste!</strong>
#     </h2>
