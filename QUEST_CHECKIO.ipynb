# %% [markdown]
# <a href="https://colab.research.google.com/github/Dannatinjaca/PROGCOM-A/blob/main/QUEST_CHECKIO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# > Agregar bloque entrecomillado![QUEST CHECKIO .jpg](data:image/jpeg;base64,...)
